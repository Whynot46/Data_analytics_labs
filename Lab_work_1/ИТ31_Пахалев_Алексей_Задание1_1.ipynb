# %% [markdown]
# 1. Получите доступ к библиотеке Pandas, используя имя
# переменной pd.
# 2. Создайте список music в 5 парами «имя вашего
# любимого исполнителя – название его песни».
# 3. Создайте список entries с названиями для двух
# столбцов – artist и track.
# 4. Используя конструктор DataFrame(), создайте таблицу из списка ваших любимых исполнителей music и списка столбцов entries. Сохраните таблицу в переменной playlist и выведите эту сборную таблицу на экран.

# %%
import pandas as pd

music = [
    ["Lana Del Rey", "Summertime Sadnes"],
    ["Минаева", "Шоколадка"],
    ["Цой", "Группа крови"],
    ["Скриптонит", "Положение"],
    ["Элман", "Черная любовь"]
]
track = ["artist", "music"]

df = pd.DataFrame(data=music, columns=track)

df
# Out:
#          artist              music
# 0  Lana Del Rey  Summertime Sadnes
# 1       Минаева          Шоколадка
# 2           Цой       Группа крови
# 3    Скриптонит          Положение
# 4         Элман      Черная любовь
